# %% [markdown]
# # **環境設定**

# %%
# https://app.roboflow.com/lab-niabe/tooth_data_v1_0308_gray_ahe_01/1

# %%
#確認路徑
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
#安裝套件與引用yolo
# !pip install ultralytics

from IPython import display
display.clear_output()
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)

# %%
#建立資料集路徑，記得替換{HOME}
HOME= '/content'
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

#下載roboflow套件並引入自定義圖片(查看說明文件第一點)
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("lab-niabe").project("tooth_data_v1_0308_gray_ahe_01")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.22)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # **訓練自定義模型**
# 查看說明文件第二點更改設定(data.yaml)

# %%
# mode=train
# %cd {HOME}

# !yolo task=obb mode=train model=yolov8s-obb.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 batch=8
# Out:
# /content
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=obb, mode=train, model=yolov8s-obb.pt, data=/content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/data.yaml, epochs=10, time=None, patience=100, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/obb/train3
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 24.9MB/s]
# 2024-03-08 17:33:15.092275: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-08 17:33:15.092333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-08 17:33:15.094191: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2402614  ultralytics.nn.modules.head.OBB              [1, 1, [128, 256, 512]]
# YOLOv8s-obb summary: 250 layers, 11422166 parameters, 11422150 gradients, 29.6 GFLOPs
#
# Transferred 391/397 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/obb/train3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 115MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/labels... 103 images, 0 backgrounds, 18 corrupt: 100% 103/103 [00:00<00:00, 1561.49it/s]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/125_jpg.rf.09aba2578d1bf72374b832ae5d4f8889.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0045]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/126_jpg.rf.887552d716629debaa857e6be8fa0713.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0034]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/132_jpg.rf.b6019f38871d4c835fd2918a66c9bacc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0019]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/13_jpg.rf.7dcbb8725cd8641066a137e081c3b0f4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0174      1.0149]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/19_jpg.rf.e5b0fd0698d7a16d7b6c624253e8b32d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0141]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/24_jpg.rf.bef3dc66d984da2d1f1546ed6c5d95ce.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.009]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/30_jpg.rf.7687cd706de52d3f29b3013c9e50df58.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0325]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/37_jpg.rf.575535c280af3435d780249f548c8977.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0667]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/43_jpg.rf.5c165c98c7e8e563e67f7c6da4e7708a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0018]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/48_jpg.rf.1ad04342ff0247db3c7fca6a48437f5c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0326]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/59_jpg.rf.5ea2862d37ac45508f9568d5a8075ac0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0308      1.0353]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/74_jpg.rf.5366a5bff222c25ca74e6802289ad896.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0357      1.0267]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/76_jpg.rf.a72d25bc8236f2055201b4db9ec44634.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0119]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/79_jpg.rf.f08bf9d59ee28e898d9240462aec2a3e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0447      1.0733]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/80_jpg.rf.afe6814971088df43f9dd3d057419ea8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0827      1.0154]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/87_jpg.rf.ea0573efabf2f0b226a2be46d2ef9bee.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0074]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/95_jpg.rf.cbc7a2b13330427083232efa472fd66c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0246]
# train: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/images/99_jpg.rf.985ccf79039faaabbb7aa250f135aee7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0235]
# train: New cache created: /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/labels... 29 images, 0 backgrounds, 3 corrupt: 100% 29/29 [00:00<00:00, 639.86it/s]
# val: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/images/131_jpg.rf.f0011e8ecc7f59740105c8baffe38f27.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0226      1.0292]
# val: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/images/140_jpg.rf.03583d65f3d9e6bc47197c5103ad05ca.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.054]
# val: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/images/98_jpg.rf.69c53088451d65927932907fca015cfc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0068]
# val: New cache created: /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/labels.cache
# Plotting labels to runs/obb/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 63 weight(decay=0.0), 73 weight(decay=0.0005), 72 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/obb/train3
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      2.29G       2.25      2.847      3.914         14        640: 100% 11/11 [00:05<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  3.05it/s]
#                    all         26         76       0.27       0.25      0.178     0.0323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      2.34G      1.589      1.979       3.15         14        640: 100% 11/11 [00:02<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.49it/s]
#                    all         26         76       0.87      0.882      0.922      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10       2.4G      1.207      1.426      2.898         15        640: 100% 11/11 [00:01<00:00,  6.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  6.90it/s]
#                    all         26         76      0.876      0.895      0.934      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10       2.4G      1.092      1.284      2.779         15        640: 100% 11/11 [00:01<00:00,  6.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  6.90it/s]
#                    all         26         76      0.832      0.947      0.941      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      2.41G      1.113      1.181      2.761         15        640: 100% 11/11 [00:01<00:00,  5.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  8.22it/s]
#                    all         26         76      0.899      0.961      0.973      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      2.39G      1.067      1.062      2.721         14        640: 100% 11/11 [00:01<00:00,  6.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  8.62it/s]
#                    all         26         76      0.939      0.947      0.988      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10       2.4G      1.157      1.048       2.58         16        640: 100% 11/11 [00:01<00:00,  6.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  9.14it/s]
#                    all         26         76      0.972      0.917      0.984      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      2.42G      1.078      1.025      2.472         12        640: 100% 11/11 [00:01<00:00,  6.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  8.69it/s]
#                    all         26         76      0.947      0.949      0.982      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      2.41G      1.001     0.9342      2.201         14        640: 100% 11/11 [00:02<00:00,  5.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.38it/s]
#                    all         26         76      0.905          1      0.984      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10       2.4G     0.9141     0.8806      2.469         13        640: 100% 11/11 [00:01<00:00,  6.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  8.11it/s]
#                    all         26         76      0.923      0.987      0.987      0.741
#
# 10 epochs completed in 0.012 hours.
# Optimizer stripped from runs/obb/train3/weights/last.pt, 23.1MB
# Optimizer stripped from runs/obb/train3/weights/best.pt, 23.1MB
#
# Validating runs/obb/train3/weights/best.pt...
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-obb summary (fused): 187 layers, 11411958 parameters, 0 gradients, 29.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  3.56it/s]
#                    all         26         76      0.972      0.919      0.984      0.776
# Speed: 0.8ms preprocess, 10.3ms inference, 0.0ms loss, 13.5ms postprocess per image
# Results saved to runs/obb/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# from PIL import Image
# 查看訓練結果，記得注意路徑

# %cd {HOME}
# Image(filename=f'{HOME}/runs/obb/train/confusion_matrix.png', width=600)
Image.open(f'{HOME}/runs/obb/train3/confusion_matrix.png')
# Out:
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
# 查看訓練結果，記得注意路徑

# %cd {HOME}
Image.open(f'{HOME}/runs/obb/train3/results.png')
# Out:
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
# mode=val，記得注意路徑
# %cd {HOME}

# !yolo task=obb mode=val model={HOME}/runs/obb/train3/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-obb summary (fused): 187 layers, 11411958 parameters, 0 gradients, 29.4 GFLOPs
# val: Scanning /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/labels.cache... 29 images, 0 backgrounds, 3 corrupt: 100% 29/29 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/images/131_jpg.rf.f0011e8ecc7f59740105c8baffe38f27.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0226      1.0292]
# val: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/images/140_jpg.rf.03583d65f3d9e6bc47197c5103ad05ca.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.054]
# val: WARNING ⚠️ /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/valid/images/98_jpg.rf.69c53088451d65927932907fca015cfc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0068]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all         26         76      0.972       0.92      0.984      0.776
# Speed: 1.3ms preprocess, 32.5ms inference, 0.0ms loss, 15.2ms postprocess per image
# Results saved to runs/obb/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# mode=predict，記得注意路徑
# %cd {HOME}
# !yolo task=obb mode=predict model={HOME}/runs/obb/train3/weights/best.pt conf=0.5 source={dataset.location}/test/images save=true
# Out:
# /content
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-obb summary (fused): 187 layers, 11411958 parameters, 0 gradients, 29.4 GFLOPs
#
# image 1/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/120_jpg.rf.4e79de143f978dae5e54aee05d178e08.jpg: 640x640 17.3ms
# image 2/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/121_jpg.rf.d3aa5b5268765f1b6a26aa3af6be3001.jpg: 640x640 17.3ms
# image 3/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/141_jpg.rf.a1f718ca59620f1d011dddae9202fb3b.jpg: 640x640 17.2ms
# image 4/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/142_jpg.rf.618f93a64b50a4cc9fe8566e8b015666.jpg: 640x640 17.2ms
# image 5/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/145_jpg.rf.c16f75f9c35106b384bb57bd16436f22.jpg: 640x640 17.2ms
# image 6/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/148_jpg.rf.4e6eba23b0044d9d5b976ac68e83d0f1.jpg: 640x640 17.2ms
# image 7/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/22_jpg.rf.c7ab5a91de9e1d7b4f7173883b64b521.jpg: 640x640 17.2ms
# image 8/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/27_jpg.rf.d0ff0b89a85458c35248aa4c9209a88c.jpg: 640x640 13.6ms
# image 9/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/39_jpg.rf.1db0490521503837baa4fe76e8dd2f8c.jpg: 640x640 13.5ms
# image 10/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/41_jpg.rf.c2a40410f3bdfb55b000db966d6499c0.jpg: 640x640 13.6ms
# image 11/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/51_jpg.rf.f119e717a4cc894ad04a2968ec42b634.jpg: 640x640 13.5ms
# image 12/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/7_jpg.rf.133936753ad97100b361a522971e9744.jpg: 640x640 13.5ms
# image 13/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/88_jpg.rf.71670dc61f4821bc145fbd983ab181f3.jpg: 640x640 13.6ms
# image 14/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/96_jpg.rf.9b7a24fc8f2a668a95e820c3840cbd6e.jpg: 640x640 12.3ms
# image 15/15 /content/datasets/tooth_data_v1_0308_GRAY_AHE_01-1/test/images/9_jpg.rf.d8f71aed0a9e83f131b178f196650d2f.jpg: 640x640 12.3ms
# Speed: 1.4ms preprocess, 15.1ms inference, 16.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/obb/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# 將測試結果一張張輸出給我們看
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/obb/predict/*.jpg'):
      display(Image(filename=image_path))
      print("\n")

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
# model = YOLO(f'{HOME}/runs/obb/yolov8s-obb.pt')
# model = YOLO(f'{HOME}/runs/obb/yolov8n.pt')
model = YOLO(f'{HOME}/runs/obb/train/weights/best.pt')


# Run inference on an image
results = model(f'{dataset.location}/test/images/118_jpg.rf.8530b1481c1b4392f8f760b990f4dc52.jpg')  # results list

# View results
for r in results:
    #display(Image(filename=image_path))
    #print("\n")
    #print(r.boxes)  # print the Boxes object containing the detection bounding boxes
    #print(r.path)
    print(r.obb)
    print("\n")
    print(r.names)
# Out:
# image 1/1 /content/datasets/test_1112_01_apical-lesion_multi-1/test/images/118_jpg.rf.8530b1481c1b4392f8f760b990f4dc52.jpg: 640x640 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.OBB object with attributes:
#
# cls: tensor([0., 0., 0.], device='cuda:0')
# conf: tensor([0.9263, 0.2871, 0.2556], device='cuda:0')
# data: tensor([[175.3352, 164.1125, 218.0141,  73.4764,   1.6561,   0.9263,   0.0000],
#         [143.5922,  47.7854, 143.3020,  65.9245,   1.4279,   0.2871,   0.0000],
#         [221.2945, 138.4169, 213.5906,  69.2935,   1.4393,   0.2556,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (300, 300)
# shape: torch.Size([3, 7])
# xywhr: tensor([[175.3352, 164.1125, 218.0141,  73.4764,   1.6561],
#         [143.5922,  47.7854, 143.3020,  65.9245,   1.4279],
#         [221.2945, 138.4169, 213.5906,  69.2935,   1.4393]], device='cuda:0')
# xyxy: tensor([[129.4401,  52.3709, 221.2302, 275.8541],
#         [100.7622, -27.8295, 186.4221, 123.4002],
#         [172.9476,  28.0014, 269.6413, 248.8322]], device='cuda:0')
# xyxyxyxy: tensor([[[129.4401, 269.5918],
#          [202.6492, 275.8541],
#          [221.2302,  58.6332],
#          [148.0212,  52.3709]],
#
#         [[121.1695, 123.4002],
#          [186.4221, 114.0120],
#          [166.0148, -27.8295],
#          [100.7622, -18.4413]],
#
#         [[200.9457, 248.8322],
#          [269.6413, 239.7491],
#          [241.6432,  28.0014],
#          [172.9476,  37.0847]]], device='cuda:0')
# xyxyxyxyn: tensor([[[ 0.4315,  0.8986],
#          [ 0.6755,  0.9195],
#          [ 0.7374,  0.1954],
#          [ 0.4934,  0.1746]],
#
#         [[ 0.4039,  0.4113],
#          [ 0.6214,  0.3800],
#          [ 0.5534, -0.0928],
#          [ 0.3359, -0.0615]],
#
#         [[ 0.6698,  0.8294],
#          [ 0.8988,  0.7992],
#          [ 0.8055,  0.0933],
#          [ 0.5765,  0.1236]]], device='cuda:0')
# {0: 'apical_lesion'}

# %% [markdown]
# # **額外功能**

# %%
#這格選用 他是為了把之前的yolov5 OBB 轉 yolov8 OBB，現在roboflow已經有相關的匯出支援(若我們更改使用工具可能會用到)
import os

# Define the classes and their corresponding indices
class_names = ['0: apical_lesion']
class_indices = {name: index for index, name in enumerate(class_names)}


# Image dimensions
img_width, img_height = 640, 640

# Path to the folder containing the annotation files
folder_path = '/content/datasets/test_1112_01_apical-lesion_multi-1/valid/labels'
#folder_path = '/content/datasets/test_1112_01_apical-lesion_multi-1/train/labels'
#folder_path = '/content/datasets/test_1112_01_apical-lesion_multi-1/tst/labels'


# Function to normalize coordinates
def normalize_coordinates(coord, max_value):
    return float(coord) / max_value

# Process each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # assuming the annotation files are .txt files
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            lines = file.readlines()


        new_lines = []
        for line in lines:
            parts = line.strip().split(' ')
            if len(parts) == 10:
                # Extract label and coordinates
                label = parts[-2]
                coords = parts[:8]

                # Get the class index
                class_index = class_indices.get(label, -1)
                if class_index != -1:
                    # Normalize coordinates
                    normalized_coords = [normalize_coordinates(coords[i], img_width if i % 2 == 0 else img_height) for i in range(8)]

                    # Convert to the desired format and add to new lines
                    new_line = f"{class_index} " + " ".join(map(str, normalized_coords))
                    new_lines.append(new_line)

        # Write the converted lines to a new file or overwrite the existing file
        with open(file_path, 'w') as file:
            file.write('\n'.join(new_lines))
